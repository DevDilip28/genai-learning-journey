# %% [markdown]
# ### Tokenization

# %%
import nltk
from nltk.tokenize.punkt import PunktSentenceTokenizer

# Direct tokenizer load
tokenizer = PunktSentenceTokenizer()

text = "Hello world. How are you?"
print(tokenizer.tokenize(text))
# Out:
# ['Hello world.', 'How are you?']

# %%
import nltk
from nltk.tokenize.punkt import PunktSentenceTokenizer

tokenizer = PunktSentenceTokenizer()

corpus = """Hello world! This is a test corpus for the language model.
It contains multiple sentences, and it is designed to help us evaluate the performance of our model. 
The more data we have, the better our model will perform.
"""

sentence = tokenizer.tokenize(corpus)
print(sentence)
# Out:
# ['Hello world!', 'This is a test corpus for the language model.', 'It contains multiple sentences, and it is designed to help us evaluate the performance of our model.', 'The more data we have, the better our model will perform.']

# %%
from nltk.tokenize import  word_tokenize

words = word_tokenize(sentence) 
print(words)

# %%
from nltk.tokenize import TreebankWordTokenizer

tokenizer = TreebankWordTokenizer()
words = tokenizer.tokenize(corpus)
print(words)
# Out:
# ['Hello', 'world.', 'How', 'are', 'you', '?', 'I', 'am', 'learning', 'NLP', '.']

# %%
vocab = set(words)
print(vocab)
# Out:
# {'are', '?', '.', 'world.', 'NLP', 'am', 'I', 'learning', 'Hello', 'you', 'How'}

# %% [markdown]
# ### Stemming - word ko uske root/base form me convert karna (approximate form)
#
# 👉 Simple language:
#
# playing → play
# played → play
# plays → play

# %%
from nltk.stem import PorterStemmer

stemmer = PorterStemmer()

words = ["running", "runs", "easily", "fairly", "happily", "happier", "happiest", "happiness", "happily", "happier", "happiest"]

for word in words:
    print(word, "-->" + stemmer.stem(word))
# Out:
# running -->run
# runs -->run
# easily -->easili
# fairly -->fairli
# happily -->happili
# happier -->happier
# happiest -->happiest
# happiness -->happi
# happily -->happili
# happier -->happier
# happiest -->happiest

# %%
stemmer.stem("better")
# Out:
# 'better'

# %% [markdown]
# ### Snowball Stemming

# %%
from nltk.stem import SnowballStemmer

stemmer = SnowballStemmer("english")

words = ["playing", "played", "plays", "studies", "running"]

for word in words:
    print(word, "->", stemmer.stem(word))
# Out:
# playing -> play
# played -> play
# plays -> play
# studies -> studi
# running -> run

# %% [markdown]
# ### Lemmatization - Converts to correct base word
#
# studies → study,
#
# better → good

# %%
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

words = ["running", "runs", "easily", "fairly", "happily", "happier", "happiest", "happiness"]

for word in words:
    print(word, "-->", lemmatizer.lemmatize(word, pos='v'))
# Out:
# running --> run
# runs --> run
# easily --> easily
# fairly --> fairly
# happily --> happily
# happier --> happier
# happiest --> happiest
# happiness --> happiness

# %% [markdown]
# ### StopWords
#
# Stopwords are common words that are usually removed from text to reduce noise and improve processing efficiency.

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Dilip
# [nltk_data]     Asdeo\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
from nltk.tokenize import TreebankWordTokenizer
from nltk.corpus import stopwords

tokenizer = TreebankWordTokenizer()

sentence = "I am going to the market and I will buy fruits"

words = tokenizer.tokenize(sentence)

stop_words = set(stopwords.words('english'))

filter_words = [w for w in words if w.lower() not in stop_words]
print(filter_words)
# Out:
# ['going', 'market', 'buy', 'fruits']

# %%
corpus = """Artificial Intelligence (AI) is transforming the world rapidly. It is being used in healthcare,
education, finance, and many other industries. AI helps machines to learn from data and make decisions.

Machine Learning is a subset of AI that focuses on building models that can learn patterns from data.
Deep Learning is a further subset that uses neural networks to solve complex problems.

Natural Language Processing (NLP) enables machines to understand human language. It is used in chatbots,
translation systems, and voice assistants like Alexa and Siri.

Data is the new oil in the digital world. The more data we have, the better our models can perform.
However, data must be clean, structured, and relevant.

As technology evolves, ethical concerns around AI are also increasing. It is important to build systems
that are fair, transparent, and accountable.
"""

# %%
from nltk.tokenize.punkt import PunktSentenceTokenizer
from nltk.tokenize import TreebankWordTokenizer
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords

sentence_tokenizer = PunktSentenceTokenizer()
sentences = sentence_tokenizer.tokenize(corpus)

word_tokenizer = TreebankWordTokenizer()

all_words = []
for s in sentences:
    all_words.extend(word_tokenizer.tokenize(s))

lemmatizer = WordNetLemmatizer()

base_words = [lemmatizer.lemmatize(word, pos='v') for word in all_words]

vocab = set(all_words)

stop_words = set(stopwords.words('english'))

filtered_words = [w for w in all_words if w.lower() not in stop_words]

print("1 --> ", sentences)
print("2 --> ", all_words)
print("3 --> ", vocab)
print("4 --> ", filtered_words)
print("5 --> ", base_words)
# Out:
# 1 -->  ['Artificial Intelligence (AI) is transforming the world rapidly.', 'It is being used in healthcare,\neducation, finance, and many other industries.', 'AI helps machines to learn from data and make decisions.', 'Machine Learning is a subset of AI that focuses on building models that can learn patterns from data.', 'Deep Learning is a further subset that uses neural networks to solve complex problems.', 'Natural Language Processing (NLP) enables machines to understand human language.', 'It is used in chatbots,\ntranslation systems, and voice assistants like Alexa and Siri.', 'Data is the new oil in the digital world.', 'The more data we have, the better our models can perform.', 'However, data must be clean, structured, and relevant.', 'As technology evolves, ethical concerns around AI are also increasing.', 'It is important to build systems\nthat are fair, transparent, and accountable.']
# ...
