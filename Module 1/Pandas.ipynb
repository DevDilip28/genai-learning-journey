# %% [markdown]
# ## 📘 Pandas
#
# ### 🔹 What is Pandas?
#
# Pandas is a **data manipulation library** used to work with structured data.
#
# 👉 Think:
# Excel / Google Sheets → but in Python
#
# ---
#
# ### 🔹 Why Pandas?
#
# Real-world data is:
# - messy
# - incomplete
# - unstructured
#
# Pandas helps to:
# - clean data
# - filter data
# - organize data

# %%
import pandas as pd

df = pd.read_csv("data.csv")
print(df)

df.head()      
df.columns     
df.info()
# Out:
#     name   age            email   salary
# 0   Amit  25.0   amit@gmail.com  50000.0
# 1   Sara  17.0   sara@gmail.com  40000.0
# 2   John   NaN   john@gmail.com  45000.0
# 3  Priya  30.0              NaN  60000.0
# 4  Rahul  22.0  rahul@gmail.com      NaN
# 5   Neha  19.0   neha@gmail.com  35000.0
# <class 'pandas.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    6 non-null      str
#  1   age     5 non-null      float64
#  2   email   5 non-null      str
#  3   salary  5 non-null      float64
# dtypes: float64(2), str(2)
# memory usage: 324.0 bytes

# %%
import pandas as pd

df = pd.read_csv("data.csv")

df = df.dropna()
df = df[df["age"] > 18]

print(df)
# Out:
#    name   age           email   salary
# 0  Amit  25.0  amit@gmail.com  50000.0
# 5  Neha  19.0  neha@gmail.com  35000.0
