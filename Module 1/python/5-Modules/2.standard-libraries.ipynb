# %% [markdown]
# ### Standard Library Overview

# %%
import array

arr = array.array('i', [1, 2, 3, 4, 5])
print(arr)
# Out:
# array('i', [1, 2, 3, 4, 5])

# %%
import math

print(math.sqrt(16))
print(math.pi)
# Out:
# 4.0
# 3.141592653589793

# %%
import random

print(random.randint(1, 100))
print(random.choice(['apple','banana','cherry']))
# Out:
# 96
# apple

# %%
### File And Directory Access

import os
print(os.getcwd())
# Out:
# c:\Users\Dilip Asdeo\OneDrive\Desktop\genai-learning-journey\python\5-Modules

# %%
os.mkdir('test_dir')

# %%
## Data Serialization

import json

data = {'name': 'Dilip', 'age': 21, 'city': 'pune'}

json_str = json.dumps(data)
print(json_str)
print(type(json_str))

parsed_data = json.loads(json_str)
print(parsed_data)
print(type(parsed_data))
# Out:
# {"name": "Dilip", "age": 21, "city": "pune"}
# <class 'str'>
# {'name': 'Dilip', 'age': 21, 'city': 'pune'}
# <class 'dict'>

# %%
## csv

import csv

with open('example.csv',mode='w',newline='') as file:
    writer=csv.writer(file)
    writer.writerow(['name','age'])
    writer.writerow(['Dilip',21])

with open('example.csv',mode='r') as file:
    reader=csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['name', 'age']
# ['Dilip', '21']

# %%
## datetime
from datetime import datetime,timedelta

now=datetime.now()
print(now)

yesterday=now-timedelta(days=1)

print(yesterday)
# Out:
# 2026-01-09 13:36:43.405104
# 2026-01-08 13:36:43.405104

# %%
## time
import time
print(time.time())
time.sleep(2)
print(time.time())
# Out:
# 1767946104.001338
# 1767946106.0018494
