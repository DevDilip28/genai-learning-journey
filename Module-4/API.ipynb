# %%
from dotenv import load_dotenv
import os 
from openai import OpenAI

load_dotenv() #load env

client = OpenAI(
    api_key=os.getenv("GROQ_API_KEY"), 
    base_url="https://api.groq.com/openai/v1" 
)

response = client.chat.completions.create(  #old method only for chat 
    model="openai/gpt-oss-20b",
    messages=[
        {
            "role": "user",
            "content": "Explain photosynthesis in one line"
        }
    ]
)

print(response.choices[0].message.content)
# Out:
# Photosynthesis is the process by which green plants use light energy to convert carbon dioxide and water into glucose and oxygen.

# %%
from openai import OpenAI
import os
client = OpenAI(
    api_key=os.environ.get("GROQ_API_KEY"),
    base_url="https://api.groq.com/openai/v1",
)

response = client.responses.create(
    input="PM of India",
    model="openai/gpt-oss-20b",
)

print(response.output_text)
# Out:
# **Narendra Modi** is the current Prime Minister of India. He has held the position since May 26 2014, leading the Bharatiya Janata Party (BJP) and serving as India's head of government.

# %%
from openai import OpenAI
import os

client = OpenAI(
    api_key=os.getenv("GROQ_API_KEY"),
    base_url="https://api.groq.com/openai/v1",
)

user_input = "Explain recursion simply one line"

# Step 1: Prepare request
try:
    response = client.responses.create(
        model="openai/gpt-oss-20b",
        input=user_input
    )

    # Step 2: Extract response
    output = response.output_text

    # Step 3: Return to user
    print(output)

except Exception as e:
    print("Error in lifecycle:", str(e))
# Out:
# Recursion is a method where a function repeatedly calls itself, each time with a simpler version of the problem, until it reaches a base case that stops the calls.

# %%
from openai import OpenAI
import os

client = OpenAI(
    api_key=os.getenv("GROQ_API_KEY"),
    base_url="https://api.groq.com/openai/v1",
)

response = client.responses.create(
    model="openai/gpt-oss-20b",
    input=[
        {"role": "system", "content": "You are a helpful friend."},
        {"role": "user", "content": "Explain recursion simply in one line."}
    ]
)

print(response.output_text)
# Out:
# Recursion is a function that calls itself repeatedly, stopping only when a simple base case is reached.

# %%
from openai import OpenAI
import os

client = OpenAI(
    api_key=os.getenv("GROQ_API_KEY"),
    base_url="https://api.groq.com/openai/v1",
)

messages = [
    {
        "role": "system", "content": "you are a helpfull assistant"
    }
]

while True:
    user_input = input("You: ")

    if user_input.lower() == "exit":
        break

    messages.append(
            {
                "role": "user", "content": user_input
            }
        )
    
    response = client.responses.create(
        model="openai/gpt-oss-20b",
        input=messages,
        max_output_tokens=2000,
        temperature=0.9,
        top_p=0.9,
    )

    reply = response.output_text

    print("AI: ", reply)

    messages.append(
        {
            "role": "assistant", "content": reply
        }
    )
# Out:
# AI:  Hello! 👋 How can I help you today?
# AI:  Nice to meet you, Dilip! How can I assist you today?
# AI:  I don’t have personal memories or access to any past conversations, so I don’t actually “know” you beyond what you share here. But I’m happy to learn more about you if you’d like—just let me know what you’re interested in chatting about or any questions you have!
# AI:  It looks like you started saying “my name is” but didn’t finish the sentence. Could you tell me what your name is? That way I can address you properly.
# AI:  I don’t actually know your name unless you tell me—so feel free to share it if you’d like! Otherwise, I’m happy to help you with whatever you need.
# AI:  Got it—hello, Dilip! 👋 How can I help you today?
# AI:  I’m not sure what your name is—could you let me know? That way I can address you correctly.
# AI:  I don’t have any way to know your name unless you tell me.
# If you’d like to share it, I’ll happily use it—otherwise, just let me know what you’d like to talk about!
